# %% [markdown]
# ### 1. Importing the required libraries for EDA

# %%
print('Hello..')
# Out:
# Hello..

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Loading the data into the data frame.

# %%
df=pd.read_excel('coffee-house-satisfactory-survey.xlsx')
df.head()
# Out:
#                       Timestamp 1. Your Gender    2. Your Age  \
# 0  2019/10/01 12:38:43 PM GMT+8         Female  From 20 to 29
# 1  2019/10/01 12:38:54 PM GMT+8         Female  From 20 to 29
# 2  2019/10/01 12:38:56 PM GMT+8           Male  From 20 to 29
# 3  2019/10/01 12:39:08 PM GMT+8         Female  From 20 to 29
# 4  2019/10/01 12:39:20 PM GMT+8           Male  From 20 to 29
#
#   3. Are you currently....? 4. What is your annual income?  \
# 0                   Student             Less than RM25,000
# 1                   Student             Less than RM25,000
# 2                  Employed             Less than RM25,000
# 3                   Student             Less than RM25,000
# 4                   Student             Less than RM25,000
#
#   5. How often do you visit Coffee House?  \
# 0                                  Rarely
# 1                                  Rarely
# 2                                 Monthly
# 3                                  Rarely
# ...

# %% [markdown]
# ### 3. Renaming the columns

# %%
df.columns=['timestamp','gender','age','occupation','income','visit_frequency','enjoying','time_spend','nearest_Coffee_Houses','membership','mostly_purchase','avg_spend_per_visit','quality_rating','price_rating','promo_importance','ambiance_rating','wifi_rating','service_rating','meet_hangout_likelihood','promo_source','continue_buying']
df.head()
# Out:
#                       timestamp  gender            age occupation  \
# 0  2019/10/01 12:38:43 PM GMT+8  Female  From 20 to 29    Student
# 1  2019/10/01 12:38:54 PM GMT+8  Female  From 20 to 29    Student
# 2  2019/10/01 12:38:56 PM GMT+8    Male  From 20 to 29   Employed
# 3  2019/10/01 12:39:08 PM GMT+8  Female  From 20 to 29    Student
# 4  2019/10/01 12:39:20 PM GMT+8    Male  From 20 to 29    Student
#
#                income visit_frequency   enjoying  \
# 0  Less than RM25,000          Rarely    Dine in
# 1  Less than RM25,000          Rarely  Take away
# 2  Less than RM25,000         Monthly    Dine in
# 3  Less than RM25,000          Rarely  Take away
# 4  Less than RM25,000         Monthly  Take away
#
#                      time_spend nearest_Coffee_Houses membership  ...  \
# 0  Between 30 minutes to 1 hour            within 1km        Yes  ...
# 1              Below 30 minutes             1km - 3km        Yes  ...
# ...

# %% [markdown]
# ### 4. Dropping irrelevant columns:

# %% [markdown]
# **we are droping "timestamp" because that is not neccessary**

# %%
df.drop('timestamp',axis=1,inplace=True)

# %% [markdown]
# ### 5. Dropping the duplicate rows

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### 6.Data understanding:

# %%
df.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.age.unique()
# Out:
# array(['From 20 to 29', 'From 30 to 39', '40 and above', 'Below 20'],
#       dtype=object)

# %%
df.occupation.unique()
# Out:
# array(['Student', 'Employed', 'Self-employed', 'Housewife'], dtype=object)

# %%
df.income.unique()
# Out:
# array(['Less than RM25,000', 'RM50,000 - RM100,000',
#        'RM25,000 - RM50,000', 'RM100,000 - RM150,000',
#        'More than RM150,000'], dtype=object)

# %%
df.visit_frequency.unique()
# Out:
# array(['Rarely', 'Monthly', 'Weekly', 'Never', 'Daily'], dtype=object)

# %%
df.time_spend.unique()
# Out:
# array(['Between 30 minutes to 1 hour', 'Below 30 minutes',
#        'More than 3 hours', 'Between 1 hour to 2 hours',
#        'Between 2 hours to 3 hours'], dtype=object)

# %%
df.nearest_Coffee_Houses.unique()
# Out:
# array(['within 1km', '1km - 3km', 'more than 3km'], dtype=object)

# %%
df.membership.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.avg_spend_per_visit.unique()
# Out:
# array(['Less than RM20', 'Around RM20 - RM40', 'More than RM40', 'Zero'],
#       dtype=object)

# %%
df.quality_rating.unique()
# Out:
# array([4, 2, 3, 5, 1], dtype=int64)

# %%
df.price_rating.unique()
# Out:
# array([3, 1, 5, 2, 4], dtype=int64)

# %%
df.promo_importance.unique()
# Out:
# array([5, 4, 3, 2, 1], dtype=int64)

# %%
df.ambiance_rating.unique()
# Out:
# array([5, 4, 3, 2, 1], dtype=int64)

# %%
df.wifi_rating.unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
df.service_rating.unique()
# Out:
# array([4, 5, 3, 2, 1], dtype=int64)

# %%
df.meet_hangout_likelihood.unique()
# Out:
# array([3, 2, 4, 5, 1], dtype=int64)

# %%
df.promo_source.unique()
# Out:
# array(['Starbucks Website/Apps;Social Media;Emails;Deal sites (fave, iprice, etc...)',
#        'Social Media;In Store displays', 'In Store displays;Billboards',
#        'Through friends and word of mouth',
#        'Starbucks Website/Apps;Social Media', 'Social Media',
#        'Starbucks Website/Apps;Social Media;Emails;Through friends and word of mouth',
#        'Starbucks Website/Apps;Social Media;Through friends and word of mouth',
#        'Social Media;Through friends and word of mouth',
#        'Social Media;Through friends and word of mouth;In Store displays',
#        'Starbucks Website/Apps', 'Emails', 'Social Media;Emails',
#        'Through friends and word of mouth;In Store displays',
#        'Social Media;In Store displays;Billboards', 'Application offer',
#        'Starbucks Website/Apps;Social Media;Through friends and word of mouth;In Store displays',
#        'In Store displays',
#        'Social Media;Through friends and word of mouth;Billboards',
# ...

# %%
df.continue_buying.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.mostly_purchase.unique()
# Out:
# array(['Coffee', 'Cold drinks;Pastries', 'Coffee;Sandwiches',
#        'Cold drinks', 'Coffee;Cold drinks',
#        'Cold drinks;Pastries;Sandwiches',
#        'Coffee;Juices;Pastries;Sandwiches', 'Coffee;Pastries;Sandwiches',
#        'Coffee;Pastries', 'Cold drinks;Juices;Pastries',
#        'Coffee;Cold drinks;Pastries;Sandwiches', 'Never', 'Never buy any',
#        'Jaws chip', 'cake', 'Pastries', 'Cold drinks;Never', 'never',
#        'Nothing', 'Coffee;Cold drinks;Juices;Pastries;Sandwiches'],
#       dtype=object)

# %% [markdown]
# ### Observations:
# - by observing the data we got to know this whole dataset is categorical type
# - all columns contain categorical information only

# %% [markdown]
# ### 7. Handling/Dropping the missing or null values:

# %%
df.isnull().sum()
# Out:
# gender                     0
# age                        0
# occupation                 0
# income                     0
# visit_frequency            0
# enjoying                   1
# time_spend                 0
# nearest_Coffee_Houses      0
# membership                 0
# mostly_purchase            0
# avg_spend_per_visit        0
# quality_rating             0
# price_rating               0
# promo_importance           0
# ambiance_rating            0
# wifi_rating                0
# service_rating             0
# meet_hangout_likelihood    0
# promo_source               1
# continue_buying            0
# dtype: int64

# %% [markdown]
# - only two columns have missing values ['enjoying','promo_source']

# %%
mode=df['enjoying'].mode()
df['enjoying'].fillna(mode[0],inplace=True)

# %%
mode=df['promo_source'].mode()
df['promo_source'].fillna(mode[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# gender                     0
# age                        0
# occupation                 0
# income                     0
# visit_frequency            0
# enjoying                   0
# time_spend                 0
# nearest_Coffee_Houses      0
# membership                 0
# mostly_purchase            0
# avg_spend_per_visit        0
# quality_rating             0
# price_rating               0
# promo_importance           0
# ambiance_rating            0
# wifi_rating                0
# service_rating             0
# meet_hangout_likelihood    0
# promo_source               0
# continue_buying            0
# dtype: int64

# %% [markdown]
# ## 8. EDA ( Exploratory Data Analysis ):

# %% [markdown]
# ### 8.1 Univariate analysis:

# %%
col=df.columns
col
# Out:
# Index(['gender', 'age', 'occupation', 'income', 'visit_frequency', 'enjoying',
#        'time_spend', 'nearest_Coffee_Houses', 'membership', 'mostly_purchase',
#        'avg_spend_per_visit', 'quality_rating', 'price_rating',
#        'promo_importance', 'ambiance_rating', 'wifi_rating', 'service_rating',
#        'meet_hangout_likelihood', 'promo_source', 'continue_buying'],
#       dtype='object')

# %%
len(col)
# Out:
# 20

# %% [markdown]
# ##

# %%
# plt.figure(figsize=(15,11))
for i in range(len(col)):
    sns.countplot(x=df[col[i]])
    plt.show()

# %%
for i in range(len(col)):
    val=df[col[i]].value_counts().values
    key=df[col[i]].value_counts().keys()
    
    plt.pie(x=val,labels=key,autopct='%.2f%%')
    plt.show()

# %% [markdown]
# ### Bi variate analysis:

# %%
df.col
# Out:
# Index(['gender', 'age', 'occupation', 'income', 'visit_frequency', 'enjoying',
#        'time_spend', 'nearest_Coffee_Houses', 'membership', 'mostly_purchase',
#        'avg_spend_per_visit', 'quality_rating', 'price_rating',
#        'promo_importance', 'ambiance_rating', 'wifi_rating', 'service_rating',
#        'meet_hangout_likelihood', 'promo_source', 'continue_buying'],
#       dtype='object')

# %% [markdown]
# 1. Gender and Retention: Analyze if there are differences in retention (continue_buying) based on gender. Use a bar chart to visualize the proportions.
# 2. Age and Frequency of Visits: Explore how age groups influence visit_frequency. This can help identify which age segments are most engaged.
# 3. Income vs. Average Spend: Investigate if there’s a relationship between income and avg_spend_per_visit. A scatter plot can illustrate any trends.
# 4. Membership Status: Check how membership (membership) affects retention. Are members

# %%
r1=pd.crosstab(df['gender'],df['continue_buying'])
r1
# Out:
# continue_buying  No  Yes
# gender
# Female           15   48
# Male             13   44

# %%
r1.plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
r1=pd.crosstab(df['visit_frequency'],df['age'])
r1
# Out:
# age              40 and above  Below 20  From 20 to 29  From 30 to 39
# visit_frequency
# Daily                       0         1              1              0
# Monthly                     3         2             16              5
# Never                       0         3              6              0
# Rarely                      3         7             57              9
# Weekly                      1         0              5              3

# %%
r1.plot(kind='bar')
# Out:
# <Axes: xlabel='visit_frequency'>

# %%
r1=pd.crosstab(df['avg_spend_per_visit'],df['income'])
r1
# Out:
# income               Less than RM25,000  More than RM150,000  \
# avg_spend_per_visit
# Around RM20 - RM40                   18                    2
# Less than RM20                       40                    1
# More than RM40                        4                    2
# Zero                                  9                    1
#
# income               RM100,000 - RM150,000  RM25,000 - RM50,000  \
# avg_spend_per_visit
# Around RM20 - RM40                       3                   12
# Less than RM20                           0                   10
# More than RM40                           0                    1
# Zero                                     0                    2
#
# income               RM50,000 - RM100,000
# avg_spend_per_visit
# Around RM20 - RM40                     10
# Less than RM20                          7
# More than RM40                          0
# Zero                                    0

# %%
r1.plot(kind='bar')
# Out:
# <Axes: xlabel='avg_spend_per_visit'>

# %%
r1=pd.crosstab(df['membership'],df['continue_buying'])
r1
# Out:
# continue_buying  No  Yes
# membership
# No               23   39
# Yes               5   55

# %%
r1.plot(kind='bar')
# Out:
# <Axes: xlabel='membership'>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='income', y='avg_spend_per_visit', hue='continue_buying')
plt.xlabel('Income')
plt.ylabel('Average Spend Per Visit')
plt.title('Income vs. Average Spend Per Visit by Customer Retention')
plt.legend(title='Continue Buying', loc='upper right')
plt.show()

# %%
# Convert 'continue_buying' to numerical values for correlation analysis
df['continue_buying_numeric'] = df['continue_buying'].apply(lambda x: 1 if x == 'Yes' else 0)

# Selecting relevant columns for correlation analysis
ratings_columns = ['quality_rating', 'price_rating', 'ambiance_rating', 'service_rating', 'continue_buying_numeric']
correlation_matrix = df[ratings_columns].corr()

# Plotting the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Correlation Matrix of Ratings and Continue Buying")
plt.show()

# %%
# Split 'promo_source' by ';' and create separate rows for each source
df_expanded = df.assign(promo_source=df['promo_source'].str.split(';')).explode('promo_source')
df_expanded['promo_source'] = df_expanded['promo_source'].str.strip()  # Remove any extra whitespace

# %%
# Calculate retention rate by promo source
retention_by_source = df_expanded.groupby('promo_source')['continue_buying'].value_counts(normalize=True).unstack().fillna(0)
retention_by_source['Retention Rate'] = retention_by_source['Yes']

# Sort by retention rate in descending order
retention_by_source = retention_by_source[['Retention Rate']].sort_values(by='Retention Rate', ascending=False)
print(retention_by_source)
# Out:
# continue_buying                    Retention Rate
# promo_source
# Billboards                               0.909091
# Emails                                   0.888889
# Starbucks Website/Apps                   0.885714
# Deal sites (fave, iprice, etc...)        0.857143
# Social Media                             0.822222
# Through friends and word of mouth        0.795918
# In Store displays                        0.761905
# Application offer                        0.000000
# Never hear                               0.000000

# %%
# Plotting retention rate by promo source
plt.figure(figsize=(12, 6))
sns.barplot(x=retention_by_source.index, y=retention_by_source['Retention Rate'], palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Promo Source')
plt.ylabel('Retention Rate')
plt.title('Customer Retention Rate by Promo Source')
plt.show()

# %% [markdown]
# ## Observations:
#
# 1. **Membership and Repeat Buying:** Customers with memberships are much more likely to keep buying than those without memberships. This shows that having a membership encourages people to stay loyal.
#
# 2. **Factors Influencing Retention:** Higher ratings for quality, price, and ambiance are linked to customers sticking around, with quality having the biggest impact. Service ratings also matter, but they don’t have as strong an effect on customer retention.
# 3. **Customer Retention Rate by Promo Source:** "Biillbords,Emails" have more impact on customer retaintion "Starbucks Website/App ,Deal Sites,Social" Media have less impact as compare to Biillbords,Emails and "Application offer & Never hear" have no impact on Customer retaintion.
#
# ## Solutions:
#
# 1. **Make Memberships More Appealing:** Adding more value to memberships (like exclusive discounts or rewards) could help keep members coming back and attract new members.
#
# 2. **Focus on Quality and Price:** Keeping product quality high and prices competitive can improve customer satisfaction and loyalty, as these are closely tied to repeat buying.
#
# 3. **Improve Ambiance:** Enhancing the atmosphere of the space (like décor, lighting, and comfort) can also make a difference in keeping customers coming back.
#
# 4. **Promo Source:** Spend money only on "Biillbords,Emails,Starbucks Website/App ,Deal Sites,Social Media" except "Application Offer & Never Hear"  for promotions.

# %% [markdown]
# ## Conclusion:
#
# **The findings show that having a membership greatly increases the chances of customers coming back. People who rate the quality, price, and ambiance highly are also more likely to continue buying, with quality being the most important factor. To keep customers loyal, it would be smart to focus on improving membership perks, keeping quality high, and making sure prices feel fair. Service is still important, but it seems to have less impact on whether customers come back compared to quality, price, and ambiance.**
